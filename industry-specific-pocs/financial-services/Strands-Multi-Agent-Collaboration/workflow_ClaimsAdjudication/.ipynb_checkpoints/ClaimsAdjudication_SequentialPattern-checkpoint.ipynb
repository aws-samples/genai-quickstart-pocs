# %% [markdown]
# # Autonomous Claims Adjudication using Agent Workflows with Strands Agents

# %% [markdown]
# ## Understanding Workflows
#
# ### What is an Agent Workflow?
# An agent workflow is a structured coordination of tasks across multiple AI agents, where each agent performs specialized functions in a defined sequence or pattern. By breaking down complex problems into manageable components and distributing them to specialized agents, workflows provide explicit control over task execution order, dependencies, and information flow, ensuring reliable outcomes for processes that require specific execution patterns.
#
# ### Components of a Workflow Architecture
# A workflow architecture consists of three key components:
#
# 1. Task Definition and Distribution
# Task Specification: Clear description of what each agent needs to accomplish
# Agent Assignment: Matching tasks to agents with appropriate capabilities
# Priority Levels: Determining which tasks should execute first when possible
# 2. Dependency Management
# Sequential Dependencies: Tasks that must execute in a specific order
# Parallel Execution: Independent tasks that can run simultaneously
# Join Points: Where multiple parallel paths converge before continuing
# 3. Information Flow
# Input/Output Mapping: Connecting one agent's output to another's input
# Context Preservation: Maintaining relevant information throughout the workflow
# State Management: Tracking the overall workflow progress
#
#
# ### When to Use a Workflow
# Workflows excel in scenarios requiring structured execution and clear dependencies:
#
# Complex Multi-Step Processes: Tasks with distinct sequential stages
# Specialized Agent Expertise: Processes requiring different capabilities at each stage
# Dependency-Heavy Tasks: When certain tasks must wait for others to complete
# Resource Optimization: Running independent tasks in parallel while managing dependencies
# Error Recovery: Retrying specific failed steps without restarting the entire process
# Long-Running Processes: Tasks requiring monitoring, pausing, or resuming capabilities
# Audit Requirements: When detailed tracking of each step is necessary
# Consider other approaches (swarms, agent graphs) for  highly collaborative problems, or situations requiring extensive agent-to-agent communication

# %% [markdown]
# ### Autonomous Claims Adjudication
#
# Claims adjudication is the process by which insurance companies process, review, validate, and assess claims to determine if they should be paid, adjusted, or denied.
#
# Here is a Generic Example of a Claim Adjudication Workflow for Auto-insurnace
#
# NOTE: THIS IS JUST AN EXAMPLE FOR ILLUSTRATION PURPOSES.

# %% [markdown]
# <!-- <p align="center">
#     <img src="./images/ClaimsAdjudicationFlow.png">
# </p> -->

# %% [markdown]
# <p align="center">
#     <img src="./images/ClaimsFlow.png">
# </p>

# %% [markdown]
# ### Workflow Pattern - Sequential
#
# In the Claims Adjudication Flow, there are tasks that have dependencies and   need to be completed before moving to the next task.
# We can use a Swarm Sequential pattern where each agent completes its task before passing the result to the next agent in the chain.
#
#
# #### Agentic Flow:
# An agent that receives an insurance claim (First Notification of Loss), retrieves policy details, validates information against external sources (e.g., repair shop estimates), completes appraisal or damage assessments, and approves payment or flags the claim for human review.
#
# Pattern —> Workflow with Sequential process

# %% [markdown]
# <p align="center">
#     <img src="./images/ClaimsStrands.drawio.png">
# </p>

# %% [markdown]
# ## 1. Quick Start with Workflow tool

# %% [markdown]
# The Strands Agents SDK provides a built-in swarm tool that simplifies the implementation of multi-agent systems, offering a quick start for users. This tool implements the shared memory.

# %%
# !pip install -r requirements.txt
# !pip install PyPDF2
# Out:
# Requirement already satisfied: strands-agents in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: strands-agents-tools in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (0.2.2)
# Requirement already satisfied: boto3<2.0.0,>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.39.14)
# Requirement already satisfied: botocore<2.0.0,>=1.29.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.39.14)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (0.17.0)
# Requirement already satisfied: mcp<2.0.0,>=1.8.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.12.2)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.30.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.35.0)
# Requirement already satisfied: opentelemetry-instrumentation-threading<1.00b0,>=0.51b0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (0.56b0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.30.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.35.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (2.11.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.13.2 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (4.13.2)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (6.0.0)
# Requirement already satisfied: aws-requests-auth<0.5.0,>=0.4.3 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.4.3)
# Requirement already satisfied: dill<0.5.0,>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.4.0)
# Requirement already satisfied: markdownify<2.0.0,>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.1.0)
# Requirement already satisfied: pillow<12.0.0,>=11.2.1 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (11.2.1)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.51 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (3.0.51)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (2.10.1)
# Requirement already satisfied: readabilipy<1.0.0,>=0.2.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.3.0)
# Requirement already satisfied: rich<15.0.0,>=14.0.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (14.0.0)
# Requirement already satisfied: slack-bolt<2.0.0,>=1.23.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.23.0)
# Requirement already satisfied: sympy<2.0.0,>=1.12.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.14.0)
# Requirement already satisfied: tenacity<10.0.0,>=9.1.2 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (9.1.2)
# Requirement already satisfied: requests>=0.14.0 in /opt/conda/lib/python3.12/site-packages (from aws-requests-auth<0.5.0,>=0.4.3->strands-agents-tools->-r requirements.txt (line 2)) (2.32.3)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents->-r requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: s3transfer<0.14.0,>=0.13.0 in /opt/conda/lib/python3.12/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents->-r requirements.txt (line 1)) (0.13.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.12/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.12/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (2.4.0)
# Requirement already satisfied: beautifulsoup4<5,>=4.9 in /opt/conda/lib/python3.12/site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (4.13.4)
# Requirement already satisfied: six<2,>=1.15 in /opt/conda/lib/python3.12/site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: anyio>=4.5 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: httpx-sse>=0.4 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (0.4.0)
# Requirement already satisfied: httpx>=0.27 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (4.23.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (2.9.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (3.0.2)
# Requirement already satisfied: starlette>=0.27 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (0.46.2)
# Requirement already satisfied: uvicorn>=0.23.1 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (0.34.2)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-api<2.0.0,>=1.30.0->strands-agents->-r requirements.txt (line 1)) (6.10.0)
# Requirement already satisfied: opentelemetry-instrumentation==0.56b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (0.56b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (1.17.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.56b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.56b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (0.56b0)
# Requirement already satisfied: packaging>=18.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.56b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (24.2)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.12/site-packages (from prompt-toolkit<4.0.0,>=3.0.51->strands-agents-tools->-r requirements.txt (line 2)) (0.2.13)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->strands-agents->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/conda/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->strands-agents->-r requirements.txt (line 1)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->strands-agents->-r requirements.txt (line 1)) (0.4.0)
# Requirement already satisfied: html5lib in /opt/conda/lib/python3.12/site-packages (from readabilipy<1.0.0,>=0.2.0->strands-agents-tools->-r requirements.txt (line 2)) (1.1)
# Requirement already satisfied: lxml in /opt/conda/lib/python3.12/site-packages (from readabilipy<1.0.0,>=0.2.0->strands-agents-tools->-r requirements.txt (line 2)) (5.4.0)
# Requirement already satisfied: regex in /opt/conda/lib/python3.12/site-packages (from readabilipy<1.0.0,>=0.2.0->strands-agents-tools->-r requirements.txt (line 2)) (2024.11.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.12/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.12/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (2.19.1)
# Requirement already satisfied: slack_sdk<4,>=3.35.0 in /opt/conda/lib/python3.12/site-packages (from slack-bolt<2.0.0,>=1.23.0->strands-agents-tools->-r requirements.txt (line 2)) (3.36.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from sympy<2.0.0,>=1.12.0->strands-agents-tools->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.12/site-packages (from anyio>=4.5->mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.12/site-packages (from anyio>=4.5->mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.12/site-packages (from beautifulsoup4<5,>=4.9->markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (2.7)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.12/site-packages (from httpx>=0.27->mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.12/site-packages (from httpx>=0.27->mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27->mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2.0.0,>=1.30.0->strands-agents->-r requirements.txt (line 1)) (3.21.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (0.25.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/conda/lib/python3.12/site-packages (from pydantic-settings>=2.5.2->mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests>=0.14.0->aws-requests-auth<0.5.0,>=0.4.3->strands-agents-tools->-r requirements.txt (line 2)) (3.4.2)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.12/site-packages (from uvicorn>=0.23.1->mcp<2.0.0,>=1.8.0->strands-agents->-r requirements.txt (line 1)) (8.2.1)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.12/site-packages (from html5lib->readabilipy<1.0.0,>=0.2.0->strands-agents-tools->-r requirements.txt (line 2)) (0.5.1)
# Requirement already satisfied: PyPDF2 in /opt/conda/lib/python3.12/site-packages (3.0.1)

# %%
from strands import Agent, tool
from strands.models.bedrock import BedrockModel
from strands_tools import think, http_request, swarm
import time
import PyPDF2
import json
import boto3
import yaml
import os
import logging
import base64
import datetime as dt
from typing import Dict, Union

# %%
def read_file(file_path):
    """
    Read and extract text from a PDF file.
    
    Args:
        file_path (str): Path to the PDF file
        
    Returns:
        str: Extracted text from the PDF
    """
    try:
        # Open the PDF file in binary read mode
        # with open(file_path, 'rb') as file:
        #     # Create a PDF reader object
        #     pdf_reader = PyPDF2.PdfReader(file)
        with open(file_path, 'r') as file:
            file = file.read()
            source_json = json.loads(file)
            
            # # Get number of pages
            # num_pages = len(pdf_reader.pages)
            # print(f"Total pages: {num_pages}")
            
            # # Extract text from each page
            # text = ""
            # for page_num in range(num_pages):
            #     page = pdf_reader.pages[page_num]
            #     text += page.extract_text()
                
            return source_json
    
    except FileNotFoundError:
        return "Error: The file was not found."
    except PyPDF2.errors.PdfReadError:
        return "Error: Invalid PDF file or the file is encrypted."
    except Exception as e:
        return f"Error: {str(e)}"

# %%
# Example usage
if __name__ == "__main__":
    # file_path = "data/FNOL.json"  # Replace with your  file path
    file_path = "./data/FNOL.json"
    fnol_event = read_file(file_path)
    # print(fnol_event)

# %%
from strands import Agent
from strands_tools import workflow

# Create an agent with workflow capability
agent = Agent(tools=[workflow])

# Create a multi-agent workflow
agent.tool.workflow(
    action="create",
    workflow_id="comprehensive_claim_adjudication",
tasks=[
    {
        "task_id": "fnol_processing",
        "description": "Extract, validate, and structure FNOL data with completeness checks",
        "system_prompt": f"""You are a Claims Data Extraction Specialist.

            ROLE: Process First Notice of Loss (FNOL) forms and extract structured claim data.
            
            INPUTS: Raw FNOL document/form data {fnol_event}
            OUTPUTS: Structured JSON with validated claim information
            
            INSTRUCTIONS:
            1. Extract key data points:
               - Policy number, claim date, incident location, claimant details
               - Incident description, damages reported, witnesses
               - Supporting documentation references
            
            2. Validate data completeness:
               - Flag missing required fields
               - Identify inconsistencies in dates/locations
               - Check format compliance (policy numbers, contact info)
            
            3. Structure output as JSON with confidence scores for each field
            4. Flag potential data quality issues with specific error codes
            5. If critical information is missing, generate specific follow-up questions
            
            ERROR HANDLING: If form is illegible or severely incomplete, flag for manual review with detailed reasoning.
            
            QUALITY CHECK: Ensure all extracted monetary amounts, dates, and identifiers are properly formatted.""",
        "priority": 5
    },
    
    {
        "task_id": "policy_verification",
        "description": "Verify policy coverage, status, and applicable terms",
        "dependencies": ["fnol_processing"],
        "system_prompt": f"""You are a Policy Verification Specialist.

            ROLE: Validate policy coverage and determine claim eligibility.
            
            INPUTS: Structured claim data, policy database access
            OUTPUTS: Policy verification report with coverage determination
            
            INSTRUCTIONS:
            1. Verify policy status:
               - Active coverage on incident date
               - Premium payment status
               - Policy limits and deductibles
            
            2. Analyze coverage applicability:
               - Match incident type to covered perils
               - Check for exclusions or limitations
               - Identify applicable sub-limits
            
            3. Calculate coverage amounts:
               - Maximum payout potential
               - Deductible applications
               - Co-insurance factors
            
            4. Flag policy issues:
               - Lapsed coverage, exclusions, fraud indicators
               - Material misrepresentation concerns
            
            OUTPUT FORMAT: Structured report with coverage determination, limits, and any red flags.
            
            DECISION LOGIC: If policy is invalid or claim not covered, provide clear denial reasoning with policy section references.""",
        "priority": 4
    },

    {
        "task_id": "fraud_detection",
        "description": "Analyze claim for fraud indicators and risk assessment",
        "dependencies": ["fnol_processing"],
        "system_prompt": f"""You are a Fraud Detection Specialist.

            ROLE: Identify potential fraud indicators and assess claim authenticity.
            
            INPUTS: Claim data, historical patterns, external data sources
            OUTPUTS: Fraud risk assessment with detailed analysis
            
            FRAUD INDICATORS TO ANALYZE:
            1. Timeline inconsistencies (reporting delays, convenient timing)
            2. Claim patterns (frequency, amounts, incident types)
            3. Documentation quality (photos, estimates, witness statements)
            4. Claimant behavior (evasiveness, excessive pressure, coaching signs)
            5. Damage consistency (impact patterns, wear indicators)
            
            RISK SCORING:
            - LOW (0-3): Standard processing
            - MEDIUM (4-6): Enhanced investigation required
            - HIGH (7-10): Special Investigation Unit referral
            
            ANALYSIS REQUIREMENTS:
            - Cross-reference similar claims in database
            - Verify incident location and timing plausibility
            - Assess damage patterns against reported cause
            - Check for staging indicators
            
            OUTPUT: Risk score with specific indicators found and recommended actions.""",
        "priority": 4
    },

    {
        "task_id": "damage_appraisal",
        "description": "Comprehensive damage assessment and repair cost estimation",
        "dependencies": ["policy_verification", "fraud_detection"],
        "system_prompt": f"""You are a Damage Appraisal Specialist.

            ROLE: Conduct thorough damage assessment and provide accurate repair cost estimates.
            
            INPUTS: Claim details, photos, estimates, policy coverage info
            OUTPUTS: Detailed appraisal report with itemized repair costs
            
            APPRAISAL PROCESS:
            1. Damage Analysis:
               - Categorize damage by type and severity
               - Distinguish pre-existing vs. incident-related damage
               - Assess structural vs. cosmetic damage
            
            2. Cost Estimation:
               - Use current market rates for materials/labor
               - Consider regional cost variations
               - Factor in quality/grade matching requirements
               - Include necessary vs. improvement upgrades
            
            3. Validation Steps:
               - Compare submitted estimates with market standards
               - Verify contractor credentials and estimates
               - Check for inflated or unnecessary repairs
            
            4. Documentation:
               - Detailed photo analysis with annotations
               - Line-item cost breakdown
               - Justification for any estimate adjustments
            
            QUALITY STANDARDS:
            - All estimates within 10% industry standard ranges
            - Clear separation of covered vs. non-covered repairs
            - Depreciation calculations where applicable
            
            RED FLAGS: Identify overpriced estimates, unnecessary repairs, or non-incident damage claims.""",
        "priority": 3
    },

    {
        "task_id": "settlement_calculation",
        "description": "Calculate final settlement amount with all applicable adjustments",
        "dependencies": ["damage_appraisal"],
        "system_prompt": f"""You are a Settlement Calculation Specialist.

            ROLE: Determine final claim payout with precise calculations and proper adjustments.
            
            INPUTS: Appraisal report, policy terms, coverage verification
            OUTPUTS: Final settlement calculation with detailed breakdown
            
            CALCULATION COMPONENTS:
            1. Base Settlement:
               - Approved repair costs
               - Replacement cost vs. actual cash value
               - Applicable coverage limits
            
            2. Adjustments:
               - Deductible applications
               - Depreciation calculations
               - Betterment considerations
               - Sales tax implications
            
            3. Additional Considerations:
               - Loss of use/additional living expenses
               - Code upgrade requirements
               - Salvage value deductions
            
            VERIFICATION REQUIREMENTS:
            - Double-check all mathematical calculations
            - Ensure compliance with policy terms
            - Validate against coverage limits
            - Confirm proper deductible application
            
            OUTPUT FORMAT:
            - Settlement summary with line-item breakdown
            - Payment authorization details
            - Required documentation for disbursement
            - Any conditions or requirements for payment
            
            COMPLIANCE: Ensure all calculations comply with state regulations and company guidelines.""",
        "priority": 2
    },

    {
        "task_id": "final_review",
        "description": "Comprehensive claim review and authorization",
        "dependencies": ["settlement_calculation"],
        "system_prompt": f"""You are a Final Review Specialist.

            ROLE: Conduct final quality assurance and authorize claim settlement.
            
            INPUTS: Complete claim file with all specialist reports
            OUTPUTS: Final authorization decision with comprehensive summary
            
            REVIEW CHECKLIST:
            1. Completeness Verification:
               - All required documentation present
               - Specialist reports consistent and logical
               - No outstanding information gaps
            
            2. Accuracy Validation:
               - Settlement calculations verified
               - Policy applications correct
               - Fraud assessment reasonable
            
            3. Compliance Check:
               - Regulatory requirements met
               - Company guidelines followed
               - Proper authorization levels
            
            4. Risk Assessment:
               - Overall claim validity confirmed
               - Appropriate settlement amount
               - No unresolved red flags
            
            DECISION OUTCOMES:
            - APPROVE: Issue payment with conditions specified
            - DENY: Provide detailed denial reasoning with policy citations
            - INVESTIGATE: Refer for additional investigation with specific requirements
            
            DOCUMENTATION: Create comprehensive claim summary for audit trail and future reference.
            
            ESCALATION: Flag any claims exceeding authority limits or requiring special handling.""",
        "priority": 1
    }
]
)
# Out:
# {'status': 'success',
#  'content': [{'text': "✅ Created modern workflow 'comprehensive_claim_adjudication' with 6 tasks"}],
#  'toolUseId': 'tooluse_workflow_277779861'}

# %%
# Execute workflow (parallel processing where possible)
adjudication_report = agent.tool.workflow(action="start", 
                    workflow_id="comprehensive_claim_adjudication",
                    )

# Check results
status = agent.tool.workflow(action="status", workflow_id="comprehensive_claim_adjudication")
# Out:
# ```json
# {
#   "extractedData": {
#     "claimInformation": {
#       "claimNumber": "CL-2023-1156789",
#       "reportDate": "2023-11-21",
#       "reportTime": "14:35:00",
#       "reportMethod": "Online",
#       "submittedBy": "Policyholder",
#       "confidenceScore": 1.0
#     },
#     "policyDetails": {
#       "policyNumber": "AUTO-P987654321",
#       "policyType": "Auto Insurance",
#       "effectiveDate": "2023-01-15",
#       "expirationDate": "2024-01-15",
#       "insuranceProvider": "Acme Insurance Company",
#       "policyStatus": "Active",
#       "confidenceScore": 1.0
#     },
#     "policyholder": {
#       "name": {
#         "firstName": "John",
#         "lastName": "Smith",
#         "fullName": "John Smith"
#       },
#       "dateOfBirth": "1985-06-12",
#       "address": {
#         "street": "123 Main Street",
#         "city": "Springfield",
#         "state": "IL",
#         "zipCode": "62704",
#         "formatted": "123 Main Street, Springfield, IL 62704"
#       },
#       "contactInformation": {
#         "homePhone": "217-555-1234",
#         "cellPhone": "217-555-5678",
#         "email": "john.smith@email.com",
#         "preferredMethod": "Email"
#       },
#       "driverLicense": {
#         "number": "S530-4281-7924",
#         "state": "IL",
#         "expirationDate": "2026-06-12",
#         "status": "Valid"
#       },
#       "confidenceScore": 1.0
#     },
#     "incidentDetails": {
#       "dateTime": {
#         "date": "2023-11-19",
#         "time": "17:45:00",
#         "formatted": "2023-11-19 17:45:00"
#       },
#       "location": {
#         "street": "456 Oak Avenue",
#         "city": "Springfield",
#         "state": "IL",
#         "zipCode": "62704",
#         "intersection": "Oak Avenue and Maple Street",
#         "coordinates": {
#           "latitude": "39.78383",
#           "longitude": "-89.65031"
#         }
#       },
#       "description": "While stopped at a red light, my vehicle was rear-ended by another car. The impact pushed my vehicle forward about 5 feet. I pulled over to the side of the road to exchange information with the other driver.",
#       "incidentType": "Vehicle Collision - Rear End",
#       "weatherConditions": {
#         "condition": "Light Rain",
#         "roadCondition": "Wet",
#         "visibility": "Good"
#       },
#       "confidenceScore": 1.0
#     },
#     "vehicleInformation": {
#       "insuredVehicle": {
#         "year": 2020,
#         "make": "Honda",
#         "model": "Accord",
#         "trim": "EX-L",
#         "vin": "1HGCV2F35LA007149",
#         "licensePlate": "ABC 1234 (IL)",
#         "mileage": 35650,
#         "primaryDriver": "John Smith",
#         "drivable": false,
#         "currentLocation": "Springfield Auto Body Shop, 789 Industrial Pkwy, Springfield, IL 62704"
#       },
#       "damageAssessment": {
#         "description": "Rear bumper dented and paint scratched, trunk lid misaligned, possible frame damage, brake lights damaged",
#         "estimatedCost": "$4,500.00",
#         "affectedAreas": [
#           "Rear bumper",
#           "Trunk",
#           "Taillights",
#           "Possible frame"
#         ],
#         "severity": "Moderate to Severe"
#       },
#       "confidenceScore": 1.0
#     },
#     "otherParties": [
#       {
#         "type": "At-Fault Driver",
#         "personalInfo": {
#           "name": "Robert Johnson",
#           "dateOfBirth": "1990-03-25",
#           "address": "789 Pine Road, Springfield, IL 62707",
#           "phone": "217-555-3456",
#           "email": "robert.johnson@email.com",
#           "driverLicense": "J525-7891-4562 (IL)"
#         },
#         "vehicle": {
#           "year": 2018,
#           "make": "Toyota",
#           "model": "Camry",
#           "vin": "4T1B11HK5JU123456",
#           "licensePlate": "XYZ 7890 (IL)",
#           "damage": "Front bumper, hood, radiator damaged"
#         },
#         "insurance": {
#           "company": "State County Insurance",
#           "policyNumber": "AUTO-56789012",
#           "phoneNumber": "800-123-4567",
#           "verified": true
#         },
#         "confidenceScore": 1.0
#       }
#     ],
#     "injuries": [
#       {
#         "injured": "John Smith (Policyholder)",
#         "description": "Neck pain, possible whiplash",
#         "medicalTreatment": {
#           "received": true,
#           "provider": "Springfield General Hospital",
#           "date": "2023-11-19",
#           "details": "X-rays taken, prescribed pain medication and neck brace"
#         },
#         "severity": "Minor to Moderate"
#       },
#       {
#         "injured": "Robert Johnson (Other Driver)",
#         "description": "Minor airbag abrasions on face and arms",
#         "medicalTreatment": {
#           "received": true,
#           "provider": "Springfield General Hospital",
#           "date": "2023-11-19",
#           "details": "Examined and released with no serious injuries"
#         },
#         "severity": "Minor"
#       }
#     ],
#     "witnesses": [
#       {
#         "name": "Sarah Williams",
#         "phone": "217-555-9012",
#         "statement": "I saw the blue sedan rear-end the policyholder's vehicle while it was completely stopped at the red light."
#       }
#     ],
#     "officialReports": {
#       "policeReport": {
#         "filed": true,
#         "reportNumber": "SPD-2023-11875",
#         "department": "Springfield Police Department",
#         "officer": "Officer Michael Johnson",
#         "badgeNumber": "42587"
#       }
#     },
#     "additionalServices": {
#       "rentalCar": {
#         "needed": true,
#         "provider": "Enterprise Rent-A-Car",
#         "startDate": "2023-11-20",
#         "expectedDuration": "14 days",
#         "vehicle": "2022 Nissan Altima",
#         "dailyRate": "$38.00"
#       }
#     }
#   },
#   "dataQualityAssessment": {
#     "overallCompleteness": "98%",
#     "criticalFieldsComplete": true,
#     "validationResults": {
#       "policyNumberFormat": "VALID",
#       "contactInformationFormat": "VALID",
#       "dateConsistency": "VALID",
#       "vinValidation": "VALID",
#       "licensePlateFormat": "VALID",
#       "monetaryAmounts": "VALID"
#     },
#     "dataQualityIssues": [
#       {
#         "severity": "LOW",
#         "category": "MISSING_OPTIONAL",
#         "description": "No photos verification status provided",
#         "field": "vehicle.photos.verified",
#         "errorCode": "OPT001"
#       }
#     ],
#     "missingRequiredFields": [],
#     "inconsistencies": []
#   },
#   "coverageAnalysis": {
#     "applicableCoverage": [
#       {
#         "type": "Collision",
#         "deductible": "$500.00",
#         "status": "APPLICABLE"
#       },
#       {
#         "type": "Medical Payments",
#         "limit": "$10,000.00",
#         "status": "APPLICABLE"
#       },
#       {
#         "type": "Rental Reimbursement",
#         "limit": "$40/day, $1,200 maximum",
#         "status": "ACTIVE"
#       }
#     ],
#     "estimatedExposure": {
#       "vehicleDamage": "$4,500.00",
#       "medicalExpenses": "TBD",
#       "rentalCosts": "$532.00",
#       "totalEstimated": "$5,032.00+"
#     }
#   },
#   "riskAssessment": {
#     "faultDetermination": "Other party at fault (rear-end collision)",
#     "liabilityRisk": "LOW",
#     "fraudIndicators": "NONE",
#     "subrogationPotential": "HIGH"
#   },
#   "nextActions": {
#     "immediate": [
#       "Schedule vehicle inspection",
#       "Obtain medical records",
#       "Contact other party's insurance",
#       "Verify rental car authorization"
#     ],
#     "followUp": [
#       "Monitor medical treatment progress",
#       "Coordinate with repair facility",
#       "Pursue subrogation claim"
#     ]
#   },
#   "processingStatus": {
#     "extractionComplete": true,
#     "validationPassed": true,
#     "readyForProcessing": true,
#     "manualReviewRequired": false,
#     "processingTimestamp": "2023-11-21T14:35:00Z"
#   }
# }
# ```
#
# **Summary:**
# - **Data Completeness:** 98% complete with all critical fields present
# - **Validation Status:** All required validations passed
# - **Processing Ready:** Yes, no manual review required
# - **Key Findings:** Clear liability (rear-end collision), multiple coverage types applicable, strong subrogation potential
# - **Estimated Exposure:** $5,032+ with potential for additional medical costs
#
# The FNOL data has been successfully extracted, validated, and structured with high confidence scores across all major categories.I'm ready to analyze a claim for fraud indicators and provide a comprehensive risk assessment. However, I don't see the specific claim data to review.
#
# To conduct a thorough fraud analysis, I'll need the following information:
#
# **REQUIRED CLAIM DATA:**
# - Claim details (incident date, location, description)
# - Claimant information and history
# - Documentation provided (photos, estimates, reports)
# - Timeline of events and reporting
# - Damage descriptions and repair estimates
# - Witness statements (if any)
# - Police reports or incident reports
#
# **ADDITIONAL HELPFUL DATA:**
# - Prior claims history
# - Policy information and coverage details
# - Third-party involvement
# - Weather conditions at time of incident
# - Claimant communication records
#
# **ANALYSIS FRAMEWORK READY:**
# ✅ Timeline consistency evaluation
# ✅ Pattern recognition algorithms
# ✅ Documentation authenticity assessment
# ✅ Behavioral indicator analysis
# ✅ Damage pattern verification
# ✅ Risk scoring matrix (0-10 scale)
#
# Please provide the claim details you'd like me to analyze, and I'll deliver a comprehensive fraud risk assessment with specific indicators, evidence evaluation, and recommended investigative actions.
#
# What claim information can you share for analysis?I understand you need policy verification services. As a Policy Verification Specialist, I'm ready to validate coverage and determine claim eligibility, but I'll need the specific claim and policy information to proceed.
#
# ## Required Information for Policy Verification:
#
# ### **Claim Details Needed:**
# - **Policy Number:** [Required]
# - **Policyholder Name:** [Required]
# - **Incident Date & Time:** [Required]
# - **Incident Type/Cause:** [Required]
# - **Claim Amount:** [Required]
#
# ### **Additional Information:**
# - Policy effective dates
# - Premium payment history
# - Previous claims on policy
# - Property/vehicle details (if applicable)
#
# ## Verification Process I'll Execute:
#
# ### **1. Policy Status Check**
# - ✓ Active coverage verification
# - ✓ Premium payment status
# - ✓ Policy renewal/lapse status
# - ✓ Coverage period validation
#
# ### **2. Coverage Analysis**
# - ✓ Peril/cause matching
# - ✓ Exclusion review
# - ✓ Limitation assessment
# - ✓ Sub-limit identification
#
# ### **3. Financial Calculations**
# - ✓ Policy limits application
# - ✓ Deductible determination
# - ✓ Co-insurance factors
# - ✓ Maximum payout calculation
#
# ### **4. Risk Assessment**
# - ✓ Fraud indicators
# - ✓ Material misrepresentation check
# - ✓ Policy violation review
#
# **Please provide the claim details and policy information so I can generate a comprehensive policy verification report with coverage determination and eligibility status.**
#
# Would you like to proceed with specific claim information, or do you need guidance on what documentation should be gathered first?# COMPREHENSIVE DAMAGE APPRAISAL FRAMEWORK
#
# ## INITIAL ASSESSMENT PROTOCOL
#
# ### 1. DAMAGE DOCUMENTATION REVIEW
# **Required Information:**
# - Claim number and incident details
# - Policy coverage limits and deductibles
# - Date of loss and discovery
# - Complete photo documentation (pre-loss if available)
# - Initial damage reports
# - Weather data/incident reports
#
# **Photo Analysis Checklist:**
# - Overall property views (4 angles minimum)
# - Close-up damage documentation
# - Interior/exterior affected areas
# - Comparative undamaged areas
# - Measurement references in photos
#
# ## 2. DAMAGE CATEGORIZATION MATRIX
#
# ### STRUCTURAL DAMAGE
# - **Foundation/Footings:** Cracks, settling, displacement
# - **Framing:** Load-bearing damage, sagging, warping
# - **Roofing System:** Decking, trusses, membrane integrity
# - **Electrical/Plumbing:** Code compliance, safety hazards
#
# ### EXTERIOR DAMAGE
# - **Roofing Materials:** Shingles, tiles, metal panels
# - **Siding/Cladding:** Impact, moisture, deterioration
# - **Windows/Doors:** Glass, frames, hardware, seals
# - **Gutters/Downspouts:** Functionality, attachment
#
# ### INTERIOR DAMAGE
# - **Flooring:** Water damage, impact, replacement needs
# - **Walls/Ceilings:** Cosmetic vs. structural repairs
# - **Fixtures/Built-ins:** Cabinets, trim, appliances
# - **HVAC Systems:** Ductwork, units, ventilation
#
# ## 3. COST ESTIMATION METHODOLOGY
#
# ### LABOR RATES (Regional Adjustment Required)
# ```
# Skilled Trades (per hour):
# - General Contractor: $85-120
# - Roofing Specialist: $75-95
# - Electrical: $90-110
# - Plumbing: $85-105
# - Flooring: $65-85
# - Paint/Finish: $55-75
# ```
#
# ### MATERIAL COST FACTORS
# - **Quality Matching:** Like-kind and quality requirements
# - **Market Fluctuations:** Current pricing vs. policy date
# - **Availability:** Supply chain impact on costs
# - **Waste Factor:** 10-15% material overage standard
#
# ### MARKUP STRUCTURE
# - Contractor overhead: 10-15%
# - Profit margin: 10-20%
# - Permit/inspection fees: 2-5%
# - Temporary protection: As needed
#
# ## 4. APPRAISAL VALIDATION PROCESS
#
# ### ESTIMATE COMPARISON METHODOLOGY
# **Three-Estimate Rule:**
# 1. Contractor submitted estimate
# 2. Independent market analysis
# 3. Regional cost database verification
#
# **Variance Analysis:**
# - ±10% = Acceptable range
# - >10-20% = Requires justification
# - >20% = Red flag investigation
#
# ### QUALITY ASSURANCE CHECKS
# - **Contractor Licensing:** Verify current credentials
# - **Insurance Coverage:** Liability and workers' comp
# - **References:** Recent similar work verification
# - **BBB Rating:** Consumer complaint history
#
# ## 5. DEPRECIATION CALCULATIONS
#
# ### STANDARD DEPRECIATION SCHEDULES
# ```
# Roofing Materials:
# - Asphalt Shingles: 20-25 years
# - Metal Roofing: 40-50 years
# - Tile/Slate: 50-75 years
#
# Flooring:
# - Carpet: 5-7 years
# - Hardwood: 25-30 years
# - Tile: 15-20 years
#
# Exterior:
# - Siding: 20-40 years (material dependent)
# - Windows: 20-25 years
# - Paint: 7-10 years
# ```
#
# ## 6. COMPREHENSIVE APPRAISAL REPORT TEMPLATE
#
# ### EXECUTIVE SUMMARY
# - Total damage estimate: $______
# - Covered damages: $______
# - Non-covered items: $______
# - Depreciation applied: $______
# - **Net claim value: $______**
#
# ### DETAILED FINDINGS
#
# **CATEGORY A: STRUCTURAL REPAIRS**
# | Item | Quantity | Unit Cost | Total | Justification |
# |------|----------|-----------|-------|---------------|
# | Foundation repair | 50 LF | $125 | $6,250 | Hairline cracks, sealant |
# | Roof decking | 15 sheets | $85 | $1,275 | Water damage replacement |
#
# **CATEGORY B: EXTERIOR RESTORATION**
# | Item | Quantity | Unit Cost | Total | Justification |
# |------|----------|-----------|-------|---------------|
# | Roof shingles | 28 squares | $450 | $12,600 | Like-kind dimensional |
# | Siding repair | 200 SF | $12 | $2,400 | Color/texture match |
#
# **CATEGORY C: INTERIOR RESTORATION**
# | Item | Quantity | Unit Cost | Total | Justification |
# |------|----------|-----------|-------|---------------|
# | Flooring replacement | 350 SF | $8.50 | $2,975 | Water-damaged hardwood |
# | Interior paint | 1,200 SF | $3.25 | $3,900 | Two-coat system |
#
# ## 7. RED FLAG IDENTIFICATION SYSTEM
#
# ### PRICING RED FLAGS
# - Estimates >25% above market average
# - Round number pricing (lacks detail)
# - Upgrade specifications beyond policy requirements
# - Emergency rates for non-emergency work
#
# ### DAMAGE RED FLAGS
# - Pre-existing conditions claimed as new damage
# - Wear/maintenance issues attributed to incident
# - Damage inconsistent with reported cause of loss
# - Contractor-driven scope expansion
#
# ### DOCUMENTATION RED FLAGS
# - Poor quality or insufficient photos
# - Missing comparative estimates
# - Unlicensed or uninsured contractors
# - Pressure tactics or urgency claims
#
# ## 8. QUALITY CONTROL CHECKLIST
#
# ### FINAL VALIDATION STEPS
# - [ ] All damage directly attributable to covered peril
# - [ ] Estimates within acceptable market ranges
# - [ ] Proper depreciation applied per policy terms
# - [ ] Code upgrade requirements identified
# - [ ] Contractor qualifications verified
# - [ ] Alternative repair methods considered
# - [ ] Salvage value accounted for
# - [ ] Temporary living expenses calculated (if applicable)
#
# ### APPROVAL THRESHOLDS
# - **Routine Claims (<$10K):** Field adjuster approval
# - **Complex Claims ($10K-50K):** Senior appraiser review
# - **Major Claims (>$50K):** Management and engineering review
#
# This framework ensures consistent, accurate, and defensible damage appraisals while protecting against inflated or fraudulent claims.I'd be happy to help calculate the final settlement amount, but I need the specific case details to provide an accurate calculation. Please provide:
#
# ## REQUIRED INFORMATION:
#
# ### **Policy Details:**
# - Coverage type (Dwelling, Personal Property, etc.)
# - Policy limits
# - Deductible amount
# - Replacement Cost vs. Actual Cash Value coverage
#
# ### **Loss Information:**
# - Total approved repair/replacement costs
# - Date of loss
# - Age of damaged items/structure
# - Cause of loss
#
# ### **Appraisal Results:**
# - Itemized repair estimates
# - Material and labor costs
# - Code upgrade requirements (if any)
#
# ### **Additional Factors:**
# - Depreciation schedules
# - Betterment considerations
# - Sales tax rate
# - Salvage value
# - Loss of use claims
# - Additional living expenses
#
# ## SAMPLE CALCULATION FRAMEWORK:
#
# ```
# BASE SETTLEMENT CALCULATION:
# ├── Approved Repair Costs: $______
# ├── Less: Depreciation: ($______)
# ├── Less: Deductible: ($______)
# ├── Less: Salvage Value: ($______)
# ├── Plus: Sales Tax: $______
# ├── Plus: Code Upgrades: $______
# └── SUBTOTAL: $______
#
# ADDITIONAL BENEFITS:
# ├── Loss of Use: $______
# ├── Additional Living Expenses: $______
# └── ADDITIONAL TOTAL: $______
#
# FINAL SETTLEMENT: $______
# ```
#
# **Please provide the case-specific information so I can calculate your exact settlement amount with all proper adjustments and compliance requirements.**# COMPREHENSIVE CLAIM REVIEW AND AUTHORIZATION
#
# ## CLAIM SUMMARY
# **Claim ID:** [To be assigned]
# **Review Date:** [Current Date]
# **Final Review Specialist:** [Assigned Specialist]
# **Authorization Level:** Senior Claims Authority
#
# ---
#
# ## COMPLETENESS VERIFICATION ✓
#
# ### Documentation Status
# - [ ] **Initial Claim Form** - Complete with all signatures
# - [ ] **Policy Documentation** - Original policy and amendments verified
# - [ ] **Supporting Evidence** - Photos, receipts, estimates collected
# - [ ] **Medical Records** (if applicable) - Certified copies obtained
# - [ ] **Police Reports** (if applicable) - Official documentation filed
# - [ ] **Witness Statements** - Notarized and consistent
# - [ ] **Expert Assessments** - Professional evaluations completed
#
# ### Specialist Reports Review
# - [ ] **Claims Adjuster Report** - Initial assessment and damage evaluation
# - [ ] **Fraud Investigation Report** - Risk analysis and verification
# - [ ] **Medical Review** (if applicable) - Treatment necessity and costs
# - [ ] **Legal Assessment** - Liability and coverage determination
# - [ ] **Financial Analysis** - Settlement calculations and reserves
#
# ---
#
# ## ACCURACY VALIDATION ✓
#
# ### Settlement Calculations Verification
# ```
# Policy Coverage Limit:     $_______________
# Deductible Amount:         $_______________
# Estimated Damages:         $_______________
# Less Depreciation:         $_______________
# Settlement Subtotal:       $_______________
# Less Deductible:          $_______________
# PROPOSED SETTLEMENT:       $_______________
# ```
#
# ### Policy Application Review
# - **Coverage Period:** Confirmed claim occurred within active period
# - **Premium Status:** Account current with no outstanding payments
# - **Policy Conditions:** All conditions and exclusions properly applied
# - **Benefit Calculations:** Accurate application of coverage formulas
#
# ---
#
# ## COMPLIANCE VERIFICATION ✓
#
# ### Regulatory Requirements
# - [ ] State insurance regulations compliance
# - [ ] Claim handling timeframes met
# - [ ] Required notifications completed
# - [ ] Fair claims practices followed
#
# ### Company Guidelines
# - [ ] Internal procedures followed
# - [ ] Authority limits respected
# - [ ] Documentation standards met
# - [ ] Quality assurance protocols completed
#
# ---
#
# ## RISK ASSESSMENT MATRIX
#
# | Risk Factor | Low | Medium | High | Assessment |
# |-------------|-----|---------|------|------------|
# | Fraud Indicators | ☐ | ☐ | ☐ | |
# | Coverage Disputes | ☐ | ☐ | ☐ | |
# | Settlement Amount | ☐ | ☐ | ☐ | |
# | Legal Exposure | ☐ | ☐ | ☐ | |
# | Precedent Impact | ☐ | ☐ | ☐ | |
#
# **Overall Risk Rating:** [LOW/MEDIUM/HIGH]
#
# ---
#
# ## FINAL AUTHORIZATION DECISION
#
# ### ☐ APPROVED FOR PAYMENT
# **Settlement Amount:** $_______________
# **Payment Method:** [Check/Electronic Transfer/Other]
# **Payment Timeline:** [Business days from authorization]
#
# **Conditions of Settlement:**
# - [ ] Release agreement execution required
# - [ ] Salvage rights retained by company
# - [ ] Future claims monitoring for related issues
# - [ ] Special handling instructions: _______________
#
# ### ☐ CLAIM DENIED
# **Primary Denial Reason:**
# - [ ] Policy exclusion applies (specify): _______________
# - [ ] Coverage lapse or non-payment
# - [ ] Fraudulent claim elements
# - [ ] Insufficient documentation
# - [ ] Other: _______________
#
# **Policy Citations:** [Reference specific policy sections]
# **Appeal Rights:** Claimant informed of appeal process and deadlines
#
# ### ☐ ADDITIONAL INVESTIGATION REQUIRED
# **Investigation Areas:**
# - [ ] Further fraud examination needed
# - [ ] Additional expert evaluation required
# - [ ] Legal consultation necessary
# - [ ] Independent medical examination
# - [ ] Other: _______________
#
# **Timeline:** Investigation to be completed within ___ days
# **Assigned Investigator:** _______________
#
# ---
#
# ## ESCALATION FLAGS
#
# ### Authority Limit Exceeded
# - [ ] Settlement amount exceeds specialist authority ($______)
# - [ ] Referred to: [Senior Management/Claims Committee]
# - [ ] Escalation Date: _______________
#
# ### Special Handling Required
# - [ ] Media attention potential
# - [ ] Legal action threatened/filed
# - [ ] Regulatory inquiry involvement
# - [ ] High-profile claimant
# - [ ] Catastrophic event claim
#
# ---
#
# ## AUDIT TRAIL DOCUMENTATION
#
# ### Key Decision Points
# 1. **Initial Assessment Findings:** _______________
# 2. **Critical Evidence Evaluated:** _______________
# 3. **Specialist Recommendations:** _______________
# 4. **Final Decision Rationale:** _______________
#
# ### Quality Assurance Markers
# - **Peer Review Completed:** [Yes/No] by _______________
# - **Supervisory Approval:** [Yes/No] by _______________
# - **Exception Approvals:** _______________
# - **File Retention Category:** [Standard/Extended/Permanent]
#
# ---
#
# ## COMMUNICATION REQUIREMENTS
#
# ### Claimant Notification
# - [ ] Decision letter prepared and reviewed
# - [ ] Payment instructions included (if approved)
# - [ ] Appeal rights explained (if denied)
# - [ ] Contact information for questions provided
#
# ### Internal Notifications
# - [ ] Accounting department (for payment processing)
# - [ ] Underwriting (for policy review)
# - [ ] Legal department (if applicable)
# - [ ] Management reporting completed
#
# ---
#
# ## FINAL CERTIFICATION
#
# **I certify that this claim has been thoroughly reviewed in accordance with company policies and industry standards. All documentation has been verified, calculations checked, and appropriate authority exercised in reaching this decision.**
#
# **Final Review Specialist:** _______________
# **License Number:** _______________
# **Date:** _______________
# **Digital Signature:** _______________
#
# ---
#
# **File Status:** [CLOSED/PENDING PAYMENT/UNDER INVESTIGATION]
# **Next Review Date:** _______________
# **Archive Date:** _______________
#
# ---
#
# *This comprehensive review serves as the official authorization document and permanent record for audit and regulatory purposes.*
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
display(adjudication_report)
# Out:
# {'status': 'success',
#  'content': [{'text': "🎉 Workflow 'comprehensive_claim_adjudication' completed successfully! (6/6 tasks succeeded - 100.0%)"}],
#  'toolUseId': 'tooluse_workflow_769021937'}
